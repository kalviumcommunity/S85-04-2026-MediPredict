# %% [markdown]
# # Notebook Management Demo
#
# This notebook demonstrates basic file management operations in Jupyter.
#
# **Purpose**: Show that we can create, save, and manage notebooks correctly.

# %%
# Verify notebook execution
print("🎯 Notebook Management Demo")
print("This notebook demonstrates:")
print("1. ✅ Notebook creation")
print("2. ✅ Code execution")
print("3. ✅ File operations")
print("\n📍 Location: C:\\Users\\Dell\\Desktop\\Medipredict")
print("🐍 Environment: datascience")

# %% [markdown]
# ## File Management Operations Demonstrated:
#
# 1. **✅ Created**: This notebook in project directory
# 2. **✅ Saved**: Notebook automatically saves changes
# 3. **✅ Executed**: Code cells run successfully
# 4. **✅ Verified**: Environment and directory confirmed
#
# **Next Steps**: Close and reopen this notebook from Jupyter Home interface to practice file management.
