# %% [markdown]
# # Understanding Notebook Cells: Code vs Markdown
#
# This notebook demonstrates intentional separation between explanation (Markdown) and execution (Code).

# %% [markdown]
# ## Step 1: Run simple Python statements
#
# The next code cell executes basic Python commands to show runtime output.

# %%
message = "Hello from a Code cell!"
print(message)
print(7 + 5)
# Out:
# Hello from a Code cell!
# 12

# %% [markdown]
# ## Step 2: Perform another simple computation
#
# The next code cell creates a small list and calculates its sum, separate from this written explanation.

# %%
numbers = [1, 2, 3, 4, 5]
squared_numbers = [n**2 for n in numbers]
print("Numbers:", numbers)
print("Squared:", squared_numbers)
print("Sum:", sum(numbers))
# Out:
# Numbers: [1, 2, 3, 4, 5]
# Squared: [1, 4, 9, 16, 25]
# Sum: 15
